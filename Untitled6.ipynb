# %% [markdown]
# <a href="https://colab.research.google.com/github/ALLASAIKAUSHI/python/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 4])
ypoints = np.array([0, 100])                           ## PYPLOT

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3,10])
ypoints = np.array([4,3])                           ## PLOTTING  1

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 8])
ypoints = np.array([3, 9])                    ## PLOTTING  2

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4, 6, 8])
ypoints = np.array([3, 8, 1, 10])                     ## PLOTTING  3

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])                         ## PLOTTING 4

plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])                  ## MARKERS 1

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt                               ## MARKERS 2
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'd')
plt.show()

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt                         ## MARKERS 3
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'p')
plt.show()

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt                       ## MARKERS 4
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'h')
plt.show()

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 4 ,6 , 5])                      ## MARKERS 5

plt.plot(ypoints, marker = '*')
plt.show()

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 4 ,6 , 5])                     ## MARKERS 6

plt.plot(ypoints, marker = 's')
plt.show()

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,7,9,6])                        ## MARKERS 7

plt.plot(ypoints, marker = '<')
plt.show()

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,7,9,6])                        ## MARKERS 7

plt.plot(ypoints, marker = '2')
plt.show()
